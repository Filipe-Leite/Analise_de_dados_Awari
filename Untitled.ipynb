# %%
import pandas as pd
import pandasql

# %% [markdown]
# # IMPORTANDO OS DADOS

# %%
df = pd.read_csv('Cópia de Awari Case DS - MoviesOnStreamingPlatforms_updated.csv')

# %% [markdown]
# # CHECANDO DADOS

# %%
df.head(50)
# Out:
#     ID                                 Title  Year  Age  IMDb Rotten Tomatoes  \
# 0    1                             Inception  2010  13+   8.8             87%
# 1    2                            The Matrix  1999  18+   8.7             87%
# 2    3                Avengers: Infinity War  2018  13+   8.5             84%
# 3    4                    Back to the Future  1985   7+   8.5             96%
# 4    5        The Good, the Bad and the Ugly  1966  18+   8.8             97%
# 5    6     Spider-Man: Into the Spider-Verse  2018   7+   8.4             97%
# 6    7                           The Pianist  2002  18+   8.5             95%
# 7    8                      Django Unchained  2012  18+   8.4             87%
# 8    9               Raiders of the Lost Ark  1981   7+   8.4             95%
# 9   10                  Inglourious Basterds  2009  18+   8.3             89%
# 10  11                           Taxi Driver  1976  18+   8.3             95%
# ...

# %%
df.columns = ['id', 'title', 'year', 'age', 'imdb', 'rotten_tomatoes', 'netflix', 'hulu', 'prime_video', 'disney+', 'type',
              'directors','genres','country', 'language', 'runtime']

# %%
df.head()
# Out:
#    id                           title  year  age  imdb rotten_tomatoes  \
# 0   1                       Inception  2010  13+   8.8             87%
# 1   2                      The Matrix  1999  18+   8.7             87%
# 2   3          Avengers: Infinity War  2018  13+   8.5             84%
# 3   4              Back to the Future  1985   7+   8.5             96%
# 4   5  The Good, the Bad and the Ugly  1966  18+   8.8             97%
#
#    netflix  hulu  prime_video  disney+  type                       directors  \
# 0        1     0            0        0     0               Christopher Nolan
# 1        1     0            0        0     0  Lana Wachowski,Lilly Wachowski
# 2        1     0            0        0     0         Anthony Russo,Joe Russo
# 3        1     0            0        0     0                 Robert Zemeckis
# 4        1     0            1        0     0                    Sergio Leone
#
#                              genres                       country  \
# ...

# %% [markdown]
# # PRODUZIDOS NO BRASIL ORDENADOS POR AVALIAÇÃO

# %%
brazil_only_order_by_imdb = pandasql.sqldf('''SELECT Title, IMDb, Country 
                                                  FROM df 
                                                      WHERE Country = 'Brasil' 
                                                         or Country = 'brasil'
                                                         or Country = 'BRASIL'
                                                         or Country = 'Brazil'
                                                         or Country = 'brazil'
                                                         or Country = 'BRAZIL'
                                                                ORDER by IMDb DESC''')

# %%
brazil_only_order_by_imdb.head(20)
# Out:
#                                    title  imdb country
# 0                           Birth Reborn   8.0  Brazil
# 1                      The Second Mother   7.8  Brazil
# 2                        Boy & the World   7.6  Brazil
# 3                       Old Lord Savanna   7.6  Brazil
# 4          Cinema, Aspirins and Vultures   7.4  Brazil
# 5                  The Edge of Democracy   7.1  Brazil
# 6                          Forever Chape   7.1  Brazil
# 7                              Laerte-se   6.9  Brazil
# 8                              Good Luck   6.7  Brazil
# 9               Whindersson Nunes: Adult   6.7  Brazil
# 10                         Ana e Vitória   6.6  Brazil
# 11    Liss Pereira: Renteniendo Liquidos   6.6  Brazil
# 12                              Hopefuls   6.6  Brazil
# 13                The Silence of the Sky   6.5  Brazil
# 14  Mauricio Meirelles: Generating Chaos   6.5  Brazil
# 15             Rafinha Bastos: Ultimatum   6.5  Brazil
# ...

# %% [markdown]
# # DIRETORES COM MAIOR MÉDIA EM TÍTULOS DISPONÍVEIS NA NETFLIX E PRIMEVIDEO AO MESMO TEMPO

# %%
imdbOrderByDirectors = pandasql.sqldf('''SELECT directors,
                                                imdb,
                                                sum(imdb)/count(directors) AS mean
                                                FROM df
                                                    WHERE netflix = '1'
                                                        AND prime_video = '1' 
                                                            GROUP BY directors
                                                                ORDER BY mean DESC''')

# %%
imdbOrderByDirectors.head()
# Out:
#                     directors  imdb  mean
# 0        Tom Barton-Humphreys   8.7  8.70
# 1                Sergio Leone   8.8  8.65
# 2                 Chris Bould   8.6  8.60
# 3              Roman Polanski   8.5  8.50
# 4  Kevin Booth,David Johndrow   8.5  8.50
